# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlotteDxD/ProPythons/blob/main/Transferindo_Arquivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Diferenças entre Open()

# %%
# Abrir um arquivo para escrita (W)
with open('arquivo.txt', 'w') as file:
    file.write('Olá, mundo!')

# %%
# Abrir um arquvio para leitura e escrita
with open('arquivo.txt', 'r+') as file:
    content = file.read()
    file.write('\nAdicionando mais conteúdo.')

# %%
#Abrir um arquivo para anexo
with open('arquivo.txt', 'a') as file:
    file.write('\nMais uma linha no final do arquivo.')
